# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"City list created with {len(cities)} city names.")
# Out:
# City list created with 618 city names.

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it's being processed (with the city number and city name).

# %%
# Set url and parameters for OpenWeatherMap API call
url = 'http://api.openweathermap.org/data/2.5/weather?'
params = {
    'q': '', #city name
    'appid': api_key,
    'units': 'imperial',}

# Iterate over cities, pulling from OpenWeatherMap API and storing result.
df = pd.DataFrame()
for idx, city in enumerate(cities):
    
    #Prepare request
    params['q'] = city
    response = requests.get(url, params)
    
    # Before each set of n requests, wait. Avoids requesting too rapidly.
    n = 50 
    if idx%n == 0: time.sleep(1)
    
    # Make request, evaluate response, and store data if received
    if (response.status_code == 200):
        print(f'Processing Record {(idx)%n+1} of Set {int((idx)/n)+1} | {city}')
        data = response.json()
        try:
            new_df_entry = {
                'City'         : data['name'],
                'Cloudiness'   : data['clouds']['all'],
                'Country'      : data['sys']['country'],
                'Date'         : data['dt'],
                'Humidity'     : data['main']['humidity'],
                'Lat'          : data['coord']['lat'],
                'Lng'          : data['coord']['lon'],
                'Max Temp'     : data['main']['temp_max'],
                'Wind Speed'   : data['wind']['speed'],}
            df = df.append(new_df_entry, ignore_index=True) #ignore_index=True is required, I think bc no index initialized
        except:
            pass
        
    elif (response.status_code == 404):
        print(f'City not found.  Skipping... | {city}')
    else:
        print(f'An unexpected error occured.  Response status code: {response.status_code}.  | {city}')
        print(response.url)
        
print('-----------------------------\nData Retrieval Complete\n----------------------------')
# Out:
# Processing Record 1 of Set 1 | mataura
# Processing Record 2 of Set 1 | faanui
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | los llanos de aridane
# Processing Record 5 of Set 1 | george
# City not found.  Skipping... | mys shmidta
# Processing Record 7 of Set 1 | kodiak
# Processing Record 8 of Set 1 | georgetown
# Processing Record 9 of Set 1 | haines junction
# City not found.  Skipping... | kerki
# City not found.  Skipping... | bengkulu
# Processing Record 12 of Set 1 | shitanjing
# City not found.  Skipping... | gangotri
# Processing Record 14 of Set 1 | busselton
# Processing Record 15 of Set 1 | alofi
# Processing Record 16 of Set 1 | lompoc
# Processing Record 17 of Set 1 | cape town
# Processing Record 18 of Set 1 | cabo san lucas
# Processing Record 19 of Set 1 | new norfolk
# Processing Record 20 of Set 1 | camiri
# Processing Record 21 of Set 1 | bambous virieux
# Processing Record 22 of Set 1 | pouebo
# Processing Record 23 of Set 1 | tuatapere
# Processing Record 24 of Set 1 | chuy
# Processing Record 25 of Set 1 | fairbanks
# Processing Record 26 of Set 1 | kavieng
# Processing Record 27 of Set 1 | itarema
# Processing Record 28 of Set 1 | norman wells
# Processing Record 29 of Set 1 | touros
# Processing Record 30 of Set 1 | farah
# City not found.  Skipping... | barentsburg
# Processing Record 32 of Set 1 | rikitea
# Processing Record 33 of Set 1 | fereydun kenar
# Processing Record 34 of Set 1 | samoylovka
# Processing Record 35 of Set 1 | leningradskiy
# Processing Record 36 of Set 1 | tasiilaq
# Processing Record 37 of Set 1 | atuona
# Processing Record 38 of Set 1 | punta arenas
# Processing Record 39 of Set 1 | vaini
# Processing Record 40 of Set 1 | concepcion de buenos aires
# Processing Record 41 of Set 1 | zirandaro
# Processing Record 42 of Set 1 | ulladulla
# City not found.  Skipping... | umm durman
# Processing Record 44 of Set 1 | veraval
# Processing Record 45 of Set 1 | kapaa
# Processing Record 46 of Set 1 | sao filipe
# Processing Record 47 of Set 1 | albany
# Processing Record 48 of Set 1 | ixtapa
# City not found.  Skipping... | taolanaro
# Processing Record 50 of Set 1 | caravelas
# Processing Record 1 of Set 2 | tiksi
# City not found.  Skipping... | ngukurr
# Processing Record 3 of Set 2 | hermanus
# Processing Record 4 of Set 2 | jega
# Processing Record 5 of Set 2 | orange cove
# Processing Record 6 of Set 2 | talnakh
# Processing Record 7 of Set 2 | lubango
# Processing Record 8 of Set 2 | dikson
# Processing Record 9 of Set 2 | chokurdakh
# Processing Record 10 of Set 2 | mastic beach
# Processing Record 11 of Set 2 | rio gallegos
# Processing Record 12 of Set 2 | cidreira
# Processing Record 13 of Set 2 | elektrougli
# Processing Record 14 of Set 2 | obregon
# Processing Record 15 of Set 2 | hilo
# Processing Record 16 of Set 2 | port elizabeth
# Processing Record 17 of Set 2 | hithadhoo
# Processing Record 18 of Set 2 | westport
# Processing Record 19 of Set 2 | lagoa
# Processing Record 20 of Set 2 | cape canaveral
# Processing Record 21 of Set 2 | sao joao do paraiso
# Processing Record 22 of Set 2 | east london
# Processing Record 23 of Set 2 | bathsheba
# City not found.  Skipping... | bairiki
# Processing Record 25 of Set 2 | bethel
# Processing Record 26 of Set 2 | port alfred
# Processing Record 27 of Set 2 | kruisfontein
# Processing Record 28 of Set 2 | clyde river
# Processing Record 29 of Set 2 | hay river
# Processing Record 30 of Set 2 | lisburn
# Processing Record 31 of Set 2 | kaitangata
# City not found.  Skipping... | chardara
# Processing Record 33 of Set 2 | yellowknife
# City not found.  Skipping... | olafsvik
# Processing Record 35 of Set 2 | srednekolymsk
# Processing Record 36 of Set 2 | hobart
# Processing Record 37 of Set 2 | samarai
# Processing Record 38 of Set 2 | mahebourg
# Processing Record 39 of Set 2 | cap malheureux
# Processing Record 40 of Set 2 | prince rupert
# Processing Record 41 of Set 2 | puerto ayora
# Processing Record 42 of Set 2 | viedma
# Processing Record 43 of Set 2 | apollonia
# Processing Record 44 of Set 2 | nikolskoye
# Processing Record 45 of Set 2 | inuvik
# City not found.  Skipping... | amderma
# Processing Record 47 of Set 2 | champerico
# Processing Record 48 of Set 2 | poya
# Processing Record 49 of Set 2 | college
# Processing Record 50 of Set 2 | kita
# Processing Record 1 of Set 3 | narsaq
# Processing Record 2 of Set 3 | port-cartier
# Processing Record 3 of Set 3 | lebu
# Processing Record 4 of Set 3 | kjollefjord
# Processing Record 5 of Set 3 | khartoum
# Processing Record 6 of Set 3 | barrow
# Processing Record 7 of Set 3 | luderitz
# Processing Record 8 of Set 3 | laguna
# Processing Record 9 of Set 3 | burnie
# Processing Record 10 of Set 3 | daru
# Processing Record 11 of Set 3 | kedrovyy
# Processing Record 12 of Set 3 | jamestown
# Processing Record 13 of Set 3 | krasnotorka
# Processing Record 14 of Set 3 | bam
# Processing Record 15 of Set 3 | bilma
# Processing Record 16 of Set 3 | carnarvon
# Processing Record 17 of Set 3 | comodoro rivadavia
# Processing Record 18 of Set 3 | ikwiriri
# Processing Record 19 of Set 3 | porto murtinho
# Processing Record 20 of Set 3 | henties bay
# Processing Record 21 of Set 3 | praia
# Processing Record 22 of Set 3 | severo-kurilsk
# Processing Record 23 of Set 3 | cherskiy
# Processing Record 24 of Set 3 | gat
# Processing Record 25 of Set 3 | rio grande city
# Processing Record 26 of Set 3 | mar del plata
# Processing Record 27 of Set 3 | vostok
# Processing Record 28 of Set 3 | port hardy
# Processing Record 29 of Set 3 | klaksvik
# Processing Record 30 of Set 3 | tura
# Processing Record 31 of Set 3 | camacha
# Processing Record 32 of Set 3 | spokane
# City not found.  Skipping... | turtkul
# Processing Record 34 of Set 3 | baruun-urt
# Processing Record 35 of Set 3 | saskylakh
# Processing Record 36 of Set 3 | vestmannaeyjar
# Processing Record 37 of Set 3 | victoria
# Processing Record 38 of Set 3 | butaritari
# Processing Record 39 of Set 3 | lorengau
# Processing Record 40 of Set 3 | kendari
# Processing Record 41 of Set 3 | pangkalanbuun
# Processing Record 42 of Set 3 | grand gaube
# Processing Record 43 of Set 3 | krasnoborsk
# Processing Record 44 of Set 3 | bluff
# Processing Record 45 of Set 3 | pisco
# Processing Record 46 of Set 3 | shiloh
# Processing Record 47 of Set 3 | avarua
# Processing Record 48 of Set 3 | teya
# Processing Record 49 of Set 3 | kokkola
# Processing Record 50 of Set 3 | puro
# Processing Record 1 of Set 4 | torbay
# Processing Record 2 of Set 4 | ilulissat
# Processing Record 3 of Set 4 | aracoiaba da serra
# Processing Record 4 of Set 4 | ploemeur
# Processing Record 5 of Set 4 | kaeo
# Processing Record 6 of Set 4 | kvam
# Processing Record 7 of Set 4 | ishigaki
# Processing Record 8 of Set 4 | khatanga
# Processing Record 9 of Set 4 | esperance
# Processing Record 10 of Set 4 | gizo
# Processing Record 11 of Set 4 | ponta do sol
# City not found.  Skipping... | santarem
# Processing Record 13 of Set 4 | honningsvag
# Processing Record 14 of Set 4 | dauriya
# Processing Record 15 of Set 4 | marsabit
# Processing Record 16 of Set 4 | tres arroyos
# Processing Record 17 of Set 4 | palana
# Processing Record 18 of Set 4 | caluquembe
# Processing Record 19 of Set 4 | mincivan
# Processing Record 20 of Set 4 | richards bay
# Processing Record 21 of Set 4 | hudson bay
# Processing Record 22 of Set 4 | rawson
# Processing Record 23 of Set 4 | vardo
# Processing Record 24 of Set 4 | saint-philippe
# City not found.  Skipping... | mullaitivu
# Processing Record 26 of Set 4 | magadan
# Processing Record 27 of Set 4 | marsa matruh
# City not found.  Skipping... | umm ruwabah
# Processing Record 29 of Set 4 | bredasdorp
# Processing Record 30 of Set 4 | fershampenuaz
# Processing Record 31 of Set 4 | kardla
# Processing Record 32 of Set 4 | constitucion
# Processing Record 33 of Set 4 | ubinskoye
# City not found.  Skipping... | zolotinka
# Processing Record 35 of Set 4 | boca do acre
# Processing Record 36 of Set 4 | puerto ayacucho
# City not found.  Skipping... | jujuy
# Processing Record 38 of Set 4 | fastovetskaya
# City not found.  Skipping... | mergui
# Processing Record 40 of Set 4 | fortuna
# Processing Record 41 of Set 4 | santiago
# City not found.  Skipping... | illoqqortoormiut
# Processing Record 43 of Set 4 | codrington
# Processing Record 44 of Set 4 | thinadhoo
# City not found.  Skipping... | belushya guba
# Processing Record 46 of Set 4 | saint-pierre
# Processing Record 47 of Set 4 | xiamen
# Processing Record 48 of Set 4 | tshane
# Processing Record 49 of Set 4 | kissamos
# Processing Record 50 of Set 4 | waipawa
# Processing Record 1 of Set 5 | narathiwat
# Processing Record 2 of Set 5 | eureka
# Processing Record 3 of Set 5 | cuamba
# Processing Record 4 of Set 5 | rocha
# Processing Record 5 of Set 5 | thompson
# Processing Record 6 of Set 5 | san ramon de la nueva oran
# Processing Record 7 of Set 5 | yaya
# Processing Record 8 of Set 5 | nepomuceno
# Processing Record 9 of Set 5 | rincon
# Processing Record 10 of Set 5 | kudahuvadhoo
# Processing Record 11 of Set 5 | saint george
# Processing Record 12 of Set 5 | kapit
# City not found.  Skipping... | attawapiskat
# Processing Record 14 of Set 5 | campiglia marittima
# Processing Record 15 of Set 5 | san patricio
# Processing Record 16 of Set 5 | komsomolskiy
# Processing Record 17 of Set 5 | bereda
# Processing Record 18 of Set 5 | buckeye
# Processing Record 19 of Set 5 | namibe
# Processing Record 20 of Set 5 | manaure
# Processing Record 21 of Set 5 | torring
# Processing Record 22 of Set 5 | ayan
# Processing Record 23 of Set 5 | palu
# Processing Record 24 of Set 5 | airai
# City not found.  Skipping... | bergen
# Processing Record 26 of Set 5 | upernavik
# Processing Record 27 of Set 5 | cayenne
# Processing Record 28 of Set 5 | salalah
# Processing Record 29 of Set 5 | arraial do cabo
# Processing Record 30 of Set 5 | shirokiy
# Processing Record 31 of Set 5 | bonavista
# Processing Record 32 of Set 5 | luwuk
# Processing Record 33 of Set 5 | gawler
# City not found.  Skipping... | vaitupu
# Processing Record 35 of Set 5 | barra do corda
# City not found.  Skipping... | khowst
# Processing Record 37 of Set 5 | faya
# Processing Record 38 of Set 5 | coruripe
# Processing Record 39 of Set 5 | puerto escondido
# Processing Record 40 of Set 5 | pevek
# City not found.  Skipping... | tsihombe
# Processing Record 42 of Set 5 | ahipara
# Processing Record 43 of Set 5 | liverpool
# Processing Record 44 of Set 5 | castro
# City not found.  Skipping... | kismayo
# Processing Record 46 of Set 5 | nabire
# Processing Record 47 of Set 5 | levelland
# Processing Record 48 of Set 5 | villa maria
# Processing Record 49 of Set 5 | souillac
# Processing Record 50 of Set 5 | qaanaaq
# Processing Record 1 of Set 6 | beringovskiy
# Processing Record 2 of Set 6 | hanna
# Processing Record 3 of Set 6 | new richmond
# Processing Record 4 of Set 6 | saint john
# Processing Record 5 of Set 6 | el sauzal
# Processing Record 6 of Set 6 | berlevag
# Processing Record 7 of Set 6 | pychas
# Processing Record 8 of Set 6 | mercedes
# Processing Record 9 of Set 6 | charleston
# Processing Record 10 of Set 6 | syasstroy
# City not found.  Skipping... | artyk
# Processing Record 12 of Set 6 | maningrida
# Processing Record 13 of Set 6 | muzhi
# Processing Record 14 of Set 6 | zhoucheng
# Processing Record 15 of Set 6 | gushi
# Processing Record 16 of Set 6 | tuktoyaktuk
# City not found.  Skipping... | marcona
# Processing Record 18 of Set 6 | vezirkopru
# Processing Record 19 of Set 6 | shyryayeve
# Processing Record 20 of Set 6 | inta
# Processing Record 21 of Set 6 | parati
# Processing Record 22 of Set 6 | jiexiu
# Processing Record 23 of Set 6 | taoudenni
# Processing Record 24 of Set 6 | vao
# Processing Record 25 of Set 6 | maldonado
# Processing Record 26 of Set 6 | shieli
# Processing Record 27 of Set 6 | kavaratti
# Processing Record 28 of Set 6 | petnehaza
# Processing Record 29 of Set 6 | hobyo
# Processing Record 30 of Set 6 | charters towers
# Processing Record 31 of Set 6 | iqaluit
# Processing Record 32 of Set 6 | nanortalik
# Processing Record 33 of Set 6 | hearst
# City not found.  Skipping... | uzhur-4
# City not found.  Skipping... | halalo
# Processing Record 36 of Set 6 | tabas
# Processing Record 37 of Set 6 | roald
# Processing Record 38 of Set 6 | wajima
# Processing Record 39 of Set 6 | altay
# Processing Record 40 of Set 6 | callaway
# Processing Record 41 of Set 6 | uray
# Processing Record 42 of Set 6 | vakhrushev
# Processing Record 43 of Set 6 | sinnamary
# Processing Record 44 of Set 6 | kieta
# Processing Record 45 of Set 6 | deputatskiy
# Processing Record 46 of Set 6 | sitka
# Processing Record 47 of Set 6 | aswan
# Processing Record 48 of Set 6 | avigliano
# Processing Record 49 of Set 6 | geraldton
# Processing Record 50 of Set 6 | katsuura
# Processing Record 1 of Set 7 | wamba
# Processing Record 2 of Set 7 | ribeira grande
# Processing Record 3 of Set 7 | mount gambier
# Processing Record 4 of Set 7 | sungairaya
# Processing Record 5 of Set 7 | saint-augustin
# Processing Record 6 of Set 7 | biak
# Processing Record 7 of Set 7 | gold coast
# City not found.  Skipping... | nizhneyansk
# Processing Record 9 of Set 7 | chamonix-mont-blanc
# Processing Record 10 of Set 7 | longyearbyen
# City not found.  Skipping... | tumannyy
# City not found.  Skipping... | chiali
# Processing Record 13 of Set 7 | guerrero negro
# Processing Record 14 of Set 7 | ngunguru
# Processing Record 15 of Set 7 | galveston
# Processing Record 16 of Set 7 | libreville
# Processing Record 17 of Set 7 | aklavik
# Processing Record 18 of Set 7 | la ronge
# Processing Record 19 of Set 7 | qaqortoq
# City not found.  Skipping... | juifang
# Processing Record 21 of Set 7 | matara
# Processing Record 22 of Set 7 | kirakira
# City not found.  Skipping... | umm jarr
# Processing Record 24 of Set 7 | sillanwali
# City not found.  Skipping... | temaraia
# Processing Record 26 of Set 7 | padang
# City not found.  Skipping... | tasbuget
# Processing Record 28 of Set 7 | avera
# Processing Record 29 of Set 7 | rosetown
# Processing Record 30 of Set 7 | ostersund
# Processing Record 31 of Set 7 | mayor pablo lagerenza
# Processing Record 32 of Set 7 | key west
# Processing Record 33 of Set 7 | hasaki
# Processing Record 34 of Set 7 | qostanay
# Processing Record 35 of Set 7 | tautira
# Processing Record 36 of Set 7 | kondopoga
# City not found.  Skipping... | acarau
# Processing Record 38 of Set 7 | oktyabrskiy
# Processing Record 39 of Set 7 | ahuimanu
# Processing Record 40 of Set 7 | mizan teferi
# City not found.  Skipping... | samusu
# Processing Record 42 of Set 7 | hegra
# Processing Record 43 of Set 7 | ponta delgada
# Processing Record 44 of Set 7 | sri aman
# Processing Record 45 of Set 7 | vanimo
# Processing Record 46 of Set 7 | nicoya
# Processing Record 47 of Set 7 | guantanamo
# Processing Record 48 of Set 7 | aripuana
# Processing Record 49 of Set 7 | murliganj
# Processing Record 50 of Set 7 | solnechnyy
# Processing Record 1 of Set 8 | nizwa
# Processing Record 2 of Set 8 | biltine
# Processing Record 3 of Set 8 | chabahar
# Processing Record 4 of Set 8 | kailua
# Processing Record 5 of Set 8 | karpogory
# City not found.  Skipping... | utiroa
# City not found.  Skipping... | koungou
# Processing Record 8 of Set 8 | saint anthony
# Processing Record 9 of Set 8 | north bend
# Processing Record 10 of Set 8 | iquitos
# Processing Record 11 of Set 8 | santa fe
# Processing Record 12 of Set 8 | bayshore gardens
# Processing Record 13 of Set 8 | mayo
# Processing Record 14 of Set 8 | belle fourche
# Processing Record 15 of Set 8 | byron bay
# City not found.  Skipping... | bossembele
# Processing Record 17 of Set 8 | mount pleasant
# Processing Record 18 of Set 8 | maues
# City not found.  Skipping... | asau
# Processing Record 20 of Set 8 | great yarmouth
# Processing Record 21 of Set 8 | matamoros
# Processing Record 22 of Set 8 | arman
# Processing Record 23 of Set 8 | altamira
# Processing Record 24 of Set 8 | hauterive
# Processing Record 25 of Set 8 | takoradi
# Processing Record 26 of Set 8 | saldanha
# Processing Record 27 of Set 8 | high level
# Processing Record 28 of Set 8 | jaciara
# Processing Record 29 of Set 8 | mount isa
# City not found.  Skipping... | grand centre
# Processing Record 31 of Set 8 | sept-iles
# Processing Record 32 of Set 8 | taltal
# Processing Record 33 of Set 8 | asuncion
# Processing Record 34 of Set 8 | provideniya
# Processing Record 35 of Set 8 | lipari
# Processing Record 36 of Set 8 | escanaba
# Processing Record 37 of Set 8 | minab
# Processing Record 38 of Set 8 | lavrentiya
# Processing Record 39 of Set 8 | shalakusha
# Processing Record 40 of Set 8 | port blair
# Processing Record 41 of Set 8 | kulu
# Processing Record 42 of Set 8 | freeport
# Processing Record 43 of Set 8 | arlit
# City not found.  Skipping... | sentyabrskiy
# Processing Record 45 of Set 8 | salamiyah
# Processing Record 46 of Set 8 | axim
# City not found.  Skipping... | saleaula
# Processing Record 48 of Set 8 | west bay
# Processing Record 49 of Set 8 | matay
# Processing Record 50 of Set 8 | lethem
# Processing Record 1 of Set 9 | ikungi
# City not found.  Skipping... | phun phin
# Processing Record 3 of Set 9 | eching
# Processing Record 4 of Set 9 | flinders
# Processing Record 5 of Set 9 | kodinar
# Processing Record 6 of Set 9 | sao bernardo
# Processing Record 7 of Set 9 | shigony
# Processing Record 8 of Set 9 | madras
# Processing Record 9 of Set 9 | hovd
# City not found.  Skipping... | phrai bung
# Processing Record 11 of Set 9 | pangoa
# Processing Record 12 of Set 9 | naranjal
# Processing Record 13 of Set 9 | jiayuguan
# Processing Record 14 of Set 9 | semey
# Processing Record 15 of Set 9 | strezhevoy
# Processing Record 16 of Set 9 | shestakovo
# Processing Record 17 of Set 9 | yatou
# Processing Record 18 of Set 9 | vestmanna
# Processing Record 19 of Set 9 | la carolina
# Processing Record 20 of Set 9 | trincomalee
# Processing Record 21 of Set 9 | vila velha
# Processing Record 22 of Set 9 | talaya
# Processing Record 23 of Set 9 | nouadhibou
# Processing Record 24 of Set 9 | mindelo
# Processing Record 25 of Set 9 | bubaque
# City not found.  Skipping... | korla
# Processing Record 27 of Set 9 | lagos
# City not found.  Skipping... | dipkarpaz
# Processing Record 29 of Set 9 | paamiut
# Processing Record 30 of Set 9 | tacuarembo
# Processing Record 31 of Set 9 | ende
# Processing Record 32 of Set 9 | raudeberg
# Processing Record 33 of Set 9 | hirado
# City not found.  Skipping... | karkaralinsk
# City not found.  Skipping... | tidore
# Processing Record 36 of Set 9 | xining
# Processing Record 37 of Set 9 | vila franca do campo
# Processing Record 38 of Set 9 | banda aceh
# Processing Record 39 of Set 9 | ketchikan
# Processing Record 40 of Set 9 | muros
# Processing Record 41 of Set 9 | coihaique
# City not found.  Skipping... | zaplyusye
# Processing Record 43 of Set 9 | boguchany
# Processing Record 44 of Set 9 | lodja
# Processing Record 45 of Set 9 | buenaventura
# Processing Record 46 of Set 9 | bulgan
# Processing Record 47 of Set 9 | kendal
# Processing Record 48 of Set 9 | fuerte olimpo
# Processing Record 49 of Set 9 | marawi
# Processing Record 50 of Set 9 | sarany
# City not found.  Skipping... | sorvag
# Processing Record 2 of Set 10 | bridlington
# Processing Record 3 of Set 10 | tucumcari
# Processing Record 4 of Set 10 | suicheng
# Processing Record 5 of Set 10 | yashkul
# Processing Record 6 of Set 10 | peachtree city
# Processing Record 7 of Set 10 | rio cuarto
# Processing Record 8 of Set 10 | dunedin
# Processing Record 9 of Set 10 | harper
# City not found.  Skipping... | chengmai
# Processing Record 11 of Set 10 | barra patuca
# Processing Record 12 of Set 10 | mabamba
# Processing Record 13 of Set 10 | savannah bight
# Processing Record 14 of Set 10 | ostrovnoy
# Processing Record 15 of Set 10 | lipany
# Processing Record 16 of Set 10 | northam
# Processing Record 17 of Set 10 | rojhan
# Processing Record 18 of Set 10 | chumphon
# Processing Record 19 of Set 10 | aden
# Processing Record 20 of Set 10 | palmer
# Processing Record 21 of Set 10 | dudinka
# Processing Record 22 of Set 10 | mishelevka
# Processing Record 23 of Set 10 | ribeira brava
# Processing Record 24 of Set 10 | yuzhno-kurilsk
# Processing Record 25 of Set 10 | jijiga
# Processing Record 26 of Set 10 | atar
# Processing Record 27 of Set 10 | kabinda
# Processing Record 28 of Set 10 | san quintin
# Processing Record 29 of Set 10 | khandyga
# Processing Record 30 of Set 10 | noumea
# Processing Record 31 of Set 10 | amzya
# Processing Record 32 of Set 10 | glasgow
# Processing Record 33 of Set 10 | hamilton
# Processing Record 34 of Set 10 | shillong
# Processing Record 35 of Set 10 | tual
# Processing Record 36 of Set 10 | denpasar
# Processing Record 37 of Set 10 | visby
# Processing Record 38 of Set 10 | khani
# Processing Record 39 of Set 10 | okhotsk
# City not found.  Skipping... | cosala
# City not found.  Skipping... | turkistan
# Processing Record 42 of Set 10 | lakes entrance
# Processing Record 43 of Set 10 | mweka
# Processing Record 44 of Set 10 | gwadar
# Processing Record 45 of Set 10 | nelson bay
# Processing Record 46 of Set 10 | husavik
# Processing Record 47 of Set 10 | kargopol
# Processing Record 48 of Set 10 | panjab
# Processing Record 49 of Set 10 | wad rawah
# Processing Record 50 of Set 10 | abbeville
# Processing Record 1 of Set 11 | kiunga
# Processing Record 2 of Set 11 | olga
# City not found.  Skipping... | nguiu
# Processing Record 4 of Set 11 | yulara
# Processing Record 5 of Set 11 | seymchan
# Processing Record 6 of Set 11 | santa helena
# Processing Record 7 of Set 11 | makakilo city
# Processing Record 8 of Set 11 | tirumullaivasal
# Processing Record 9 of Set 11 | coahuayana
# Processing Record 10 of Set 11 | dera ghazi khan
# Processing Record 11 of Set 11 | vanino
# Processing Record 12 of Set 11 | buchanan
# Processing Record 13 of Set 11 | puerto penasco
# Processing Record 14 of Set 11 | ancud
# Processing Record 15 of Set 11 | kaseda
# Processing Record 16 of Set 11 | beeville
# Processing Record 17 of Set 11 | vila do maio
# Processing Record 18 of Set 11 | chateauroux
# Processing Record 19 of Set 11 | belmonte
# Processing Record 20 of Set 11 | kathu
# Processing Record 21 of Set 11 | nishihara
# Processing Record 22 of Set 11 | south lake tahoe
# Processing Record 23 of Set 11 | buriti bravo
# Processing Record 24 of Set 11 | tayoltita
# Processing Record 25 of Set 11 | moose factory
# City not found.  Skipping... | palabuhanratu
# Processing Record 27 of Set 11 | conde
# Processing Record 28 of Set 11 | puerto montt
# Processing Record 29 of Set 11 | otane
# Processing Record 30 of Set 11 | doha
# Processing Record 31 of Set 11 | ouesso
# Processing Record 32 of Set 11 | payo
# Processing Record 33 of Set 11 | ilembo
# Processing Record 34 of Set 11 | san francisco
# Processing Record 35 of Set 11 | soure
# Processing Record 36 of Set 11 | imeni babushkina
# Processing Record 37 of Set 11 | beihai
# City not found.  Skipping... | meyungs
# Processing Record 39 of Set 11 | kualakapuas
# Processing Record 40 of Set 11 | xinyang
# Processing Record 41 of Set 11 | kashan
# Processing Record 42 of Set 11 | mitu
# City not found.  Skipping... | afmadu
# Processing Record 44 of Set 11 | bogotol
# Processing Record 45 of Set 11 | surt
# Processing Record 46 of Set 11 | senno
# Processing Record 47 of Set 11 | kil
# Processing Record 48 of Set 11 | sorong
# Processing Record 49 of Set 11 | te anau
# City not found.  Skipping... | rawannawi
# Processing Record 1 of Set 12 | kingaroy
# Processing Record 2 of Set 12 | usinsk
# Processing Record 3 of Set 12 | pacific grove
# Processing Record 4 of Set 12 | bagan
# Processing Record 5 of Set 12 | makkaveyevo
# Processing Record 6 of Set 12 | opuwo
# Processing Record 7 of Set 12 | bumba
# Processing Record 8 of Set 12 | maniitsoq
# Processing Record 9 of Set 12 | pasni
# Processing Record 10 of Set 12 | fujin
# Processing Record 11 of Set 12 | dingle
# Processing Record 12 of Set 12 | verkhovazhye
# Processing Record 13 of Set 12 | maryland heights
# Processing Record 14 of Set 12 | ust-kut
# Processing Record 15 of Set 12 | oussouye
# Processing Record 16 of Set 12 | semporna
# Processing Record 17 of Set 12 | vila
# City not found.  Skipping... | tambopata
# Processing Record 19 of Set 12 | neyshabur
# Processing Record 20 of Set 12 | bundaberg
# City not found.  Skipping... | jiroft
# Processing Record 22 of Set 12 | portland
# Processing Record 23 of Set 12 | antalaha
# Processing Record 24 of Set 12 | waverly
# Processing Record 25 of Set 12 | isangel
# Processing Record 26 of Set 12 | iztapa
# Processing Record 27 of Set 12 | clinton
# Processing Record 28 of Set 12 | boa vista
# Processing Record 29 of Set 12 | seabra
# Processing Record 30 of Set 12 | najran
# Processing Record 31 of Set 12 | victor harbor
# Processing Record 32 of Set 12 | caborca
# Processing Record 33 of Set 12 | zhaodong
# City not found.  Skipping... | pipar
# Processing Record 35 of Set 12 | vladivostok
# Processing Record 36 of Set 12 | hofn
# Processing Record 37 of Set 12 | san juan
# Processing Record 38 of Set 12 | salinopolis
# Processing Record 39 of Set 12 | neuquen
# Processing Record 40 of Set 12 | la seyne-sur-mer
# Processing Record 41 of Set 12 | acapulco
# Processing Record 42 of Set 12 | togur
# Processing Record 43 of Set 12 | the pas
# Processing Record 44 of Set 12 | bambanglipuro
# Processing Record 45 of Set 12 | menongue
# City not found.  Skipping... | khonuu
# Processing Record 47 of Set 12 | kottagudem
# Processing Record 48 of Set 12 | mehamn
# City not found.  Skipping... | marang
# Processing Record 50 of Set 12 | kargat
# Processing Record 1 of Set 13 | port-gentil
# Processing Record 2 of Set 13 | elko
# Processing Record 3 of Set 13 | preobrazheniye
# City not found.  Skipping... | yeletskiy
# Processing Record 5 of Set 13 | fare
# City not found.  Skipping... | bargal
# Processing Record 7 of Set 13 | coquimbo
# Processing Record 8 of Set 13 | hirara
# Processing Record 9 of Set 13 | nara
# Processing Record 10 of Set 13 | mbandaka
# Processing Record 11 of Set 13 | kaka
# Processing Record 12 of Set 13 | wanning
# Processing Record 13 of Set 13 | monterey
# Processing Record 14 of Set 13 | notse
# Processing Record 15 of Set 13 | linxi
# Processing Record 16 of Set 13 | miragoane
# Processing Record 17 of Set 13 | plettenberg bay
# Processing Record 18 of Set 13 | port moresby
# -----------------------------
# Data Retrieval Complete
# ----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Export to csv
print(f"{len(df)} records retrieved.")
try:
    df.to_csv(output_data_file)
    print(f"Data exported to {output_data_file}.")
except:
    print('Error. Data export failed.')

# Preview data
df.head()
# Out:
# 548 records retrieved.
# Data exported to output/cities.csv.
#                     City  Cloudiness Country          Date  Humidity    Lat  \
# 0                Mataura         0.0      NZ  1.545602e+09      78.0 -46.19
# 1                 Faanui        76.0      PF  1.545603e+09     100.0 -16.48
# 2                Ushuaia        75.0      AR  1.545599e+09      81.0 -54.81
# 3  Los Llanos de Aridane         0.0      ES  1.545601e+09      45.0  28.66
# 4                 George         0.0      NG  1.545599e+09      78.0   6.63
#
#       Lng  Max Temp  Wind Speed
# 0  168.86     60.00        4.09
# 1 -151.75     83.22       15.05
# 2  -68.31     48.20       13.87
# 3  -17.92     68.00       16.11
# 4    3.35     80.60        2.24

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Get date for plot title
raw_date = time.localtime(df['Date'][0])
date_str = time.strftime('%D', raw_date)

# Make plot
plt.scatter(x = df['Lat'], y = df['Max Temp'], edgecolors='black')

# Format plot
plt.title(f"Max Temperature vs Latitude ({date_str})")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.grid(True)

# Display plot and save to png
plt.show()
plt.savefig('output/temperature_vs_latitude.png')

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Make plot
plt.scatter(x = df['Lat'], y = df['Humidity'], edgecolors='black')

# Format plot
plt.title(f"Humidity vs. City Latitude({date_str})")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.ylim(-5,105)
plt.grid(True)

# Display plot and save to png
plt.show()
plt.savefig('output/humidity_vs_latitude.png')

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Make plot
plt.scatter(x = df['Lat'], y = df['Humidity'], edgecolors='black')

# Format plot
plt.title(f"Cloudiness vs. City Latitude({date_str})")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.ylim(-5,105)
plt.grid(True)

# Display plot and save to png
plt.show()
plt.savefig('output/cloudiness_vs_latitude.png')

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Make plot
plt.scatter(x = df['Lat'], y = df['Wind Speed'], edgecolors='black')

# Format plot
plt.title(f"Wind Speed vs. City Latitude({date_str})")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.ylim(-5,55)
plt.grid(True)

# Display plot and save to png
plt.show()
plt.savefig('output/windspeed_vs_latitude.png')
